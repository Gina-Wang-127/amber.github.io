# %% [markdown]
# # Project 2

# %% [markdown]
# In project 2, I am going to observe the relationship between two datasets.

# %% [markdown]
# 1. Plotting information from both as separate lines/points

# %% [markdown]
# a. Findex Data
#
# "The Global Findex Database" from https://www.worldbank.org/en/publication/globalfindex/download-data

# %%
# import library
import plotly.io as pio

pio.renderers.default = "notebook_connected+plotly_mimetype"

import pandas as pd
import plotly.express as px

# read and clean data
findex_df = pd.read_csv("GlobalFindexDatabase2025.csv")
years = [2014, 2017, 2021, 2024]

findex_df_clean = findex_df[
    (findex_df["mobileaccount_t_d"].notna())
    & (findex_df["mobileaccount_t_d"] != "NA")
    # & (findex_df["incomegroupwb24"] == "Lower middle income")
    & (findex_df["group"] == "all")
    & (findex_df["year"].isin(years))
].copy()

findex_df_clean["mobileaccount_t_d"] = pd.to_numeric(
    findex_df_clean["mobileaccount_t_d"], errors="coerce"
)
findex_df_clean = findex_df_clean[findex_df_clean["mobileaccount_t_d"].notna()]
# Out:
# C:\Users\Jinen\AppData\Local\Temp\ipykernel_13864\1450810609.py:10: DtypeWarning:
#
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# plot
fig = px.choropleth(
    findex_df_clean,
    locations="codewb",
    color="mobileaccount_t_d",
    hover_name="countrynewwb",
    animation_frame="year",
    title="Mobile Account Ownership Across Countries (2014-2024)",
    color_continuous_scale="Viridis",
    labels={"mobileaccount_t_d": "Mobile Account Ownership Rate"},
    projection="natural earth",
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="3bd32651-9d68-4f63-9cae-eeae8d3f5d8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3bd32651-9d68-4f63-9cae-eeae8d3f5d8e")) {                    Plotly.newPlot(                        "3bd32651-9d68-4f63-9cae-eeae8d3f5d8e",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=2014\u003cbr\u003ecodewb=%{location}\u003cbr\u003eMobile Account Ownership Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Argentina","Armenia","Bangladesh","Benin","Bolivia","Botswana","Brazil","Burkina Faso","Burundi","Cambodia","Cameroon","Chad","Chile","Colombia","Congo, Dem. Rep.","Congo, Rep.","Cote d'Ivoire","Dominican Republic","Egypt, Arab Rep.","El Salvador","Ethiopia","Gabon","Ghana","Guatemala","Guinea","Haiti","Honduras","India","Indonesia","Iran, Islamic Rep.","Jamaica","Jordan","Kenya","Lebanon","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Myanmar","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Panama","Peru","Philippines","Romania","Rwanda","Senegal","Sierra Leone","Singapore","Somalia","South Africa","Sri Lanka","Tajikistan","Tanzania","Thailand","Togo","Tunisia","Turkiye","Uganda","United Arab Emirates","Uruguay","Venezuela, RB","Viet Nam","Zambia","Zimbabwe","world","Developing economies","East Asia & Pacific (excluding high income)","Europe & Central Asia (excluding high income)","Middle East & North Africa (excluding high income)","Sub-Saharan Africa (excluding high income)","Latin America & Caribbean (excluding high income)","South Asia","High income","Low income","Lower middle income","Upper middle income
type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %% [markdown]
# The graph above illustrates the mobile account ownership across countries in 2014, 2017, 2021 and 2024.
#
# It is obvious that the mobile account ownership rate has increased in the past 10 years. Brazil, for example, has increased its rate from 0.0086 in 2014 to 0.5817 in 2024.
#
# However, many countries do not have available data in this dataset.

# %% [markdown]
# b. Mobile Network Data
#
# "Population coverage, by mobile network technology" from https://datahub.itu.int/data/?i=100095&s=430

# %%
# import data

network_df = pd.read_csv("population_coverage_by_mobile_network_technology.csv")
network_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9609 entries, 0 to 9608
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   seriesID           9609 non-null   int64
#  1   seriesCode         9609 non-null   object
#  2   seriesName         9609 non-null   object
#  3   seriesParent       0 non-null      float64
#  4   seriesUnits        9609 non-null   object
#  5   entityID           9609 non-null   int64
#  6   entityIso          9609 non-null   object
#  7   entityName         9609 non-null   object
#  8   dataValue          9609 non-null   float64
#  9   dataYear           9609 non-null   int64
#  10  dataNote           1978 non-null   object
#  11  dataSource         8745 non-null   object
#  12  seriesDescription  9609 non-null   object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 976.0+ KB

# %%
# data clean
network_df_4g = network_df[network_df["seriesName"] == "At least LTE/WiMAX"]
network_df_4g["dataValue"] = network_df_4g["dataValue"] / 100

# sort year
network_df_4g = network_df_4g.sort_values("dataYear")

network_df_4g.head()
# Out:
# C:\Users\Jinen\AppData\Local\Temp\ipykernel_13864\3762890919.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       seriesID seriesCode          seriesName  seriesParent seriesUnits  \
# 6762     19306     i271GA  At least LTE/WiMAX           NaN           %
# 7071     19306     i271GA  At least LTE/WiMAX           NaN           %
# 7733     19306     i271GA  At least LTE/WiMAX           NaN           %
# 7568     19306     i271GA  At least LTE/WiMAX           NaN           %
# 8535     19306     i271GA  At least LTE/WiMAX           NaN           %
#
#       entityID entityIso entityName  dataValue  dataYear dataNote  \
# 6762        11       DZA    Algeria     0.0000      2012      NaN
# 7071        47       CAN     Canada     0.6700      2012      NaN
# 7733       130       KWT     Kuwait     0.9500      2012      NaN
# 7568       111       ITA      Italy     0.0709      2012      NaN
# 8535       238       TZA   Tanzania     0.0534      2012      NaN
#
#                                              dataSource  \
# 6762  Ministère de la  Poste et des Technologies de ...
# 7071                                      ITU estimate.
# 7733                                      ITU estimate.
# 7568                                      ITU estimate.
# 8535                                      ITU estimate.
#
#                                       seriesDescription
# 6762  Refers to the percentage of inhabitants that a...
# 7071  Refers to the percentage of inhabitants that a...
# 7733  Refers to the percentage of inhabitants that a...
# 7568  Refers to the percentage of inhabitants that a...
# 8535  Refers to the percentage of inhabitants that a...

# %%
# plot
fig = px.choropleth(
    network_df_4g,
    locations="entityIso",
    color="dataValue",
    hover_name="entityName",
    animation_frame="dataYear",
    title="Population Coverage by LTE/WiMAX Network Across Countries",
    color_continuous_scale="Viridis",
    labels={"dataValue": "At Least LTE/WiMAX Network"},
    projection="natural earth",
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="52016ba0-af37-4f1e-b6cd-fd6d6b5b0d74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById
type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# Graph above demonstrates the population coverage by at least LTE/WiMAX (namely 4G) network across countries in the past 12 years.
#
# Intuitively, the avereage rate is high in the nearest 3 years. U.S. and Canada remains a high rate since 2014, with more than 90% of the population covered by at least LTE/WiMaX.
#
# Also, the dataset contains relatively few null values.

# %% [markdown]
# 2. Merging the datasets and plotting a derived measure

# %%
# filter

findex_df_filter = findex_df_clean[
    ["year", "codewb", "countrynewwb", "mobileaccount_t_d", "incomegroupwb24"]
]

network_df_filter = network_df_4g[["dataYear", "entityIso", "dataValue"]]
network_df_filter = network_df_filter.rename(columns={"dataValue": "4g_cover"})

# concat
merged_df = findex_df_filter.merge(
    network_df_filter,
    left_on=["year", "codewb"],
    right_on=["dataYear", "entityIso"],
    how="inner",
)
merged_df = merged_df.drop(columns=["dataYear", "entityIso"])
merged_df
# Out:
#      year codewb   countrynewwb  mobileaccount_t_d      incomegroupwb24  \
# 0    2014    AFG    Afghanistan           0.003044           Low income
# 1    2014    ARG      Argentina           0.004323  Upper middle income
# 2    2014    ARM        Armenia           0.006578  Upper middle income
# 3    2014    BGD     Bangladesh           0.026917  Lower middle income
# 4    2014    BOL        Bolivia           0.027771  Lower middle income
# ..    ...    ...            ...                ...                  ...
# 253  2024    UGA         Uganda           0.677383           Low income
# 254  2024    VEN  Venezuela, RB           0.337397  Upper middle income
# 255  2024    VNM       Viet Nam           0.387233  Lower middle income
# 256  2024    ZMB         Zambia           0.693108           Low income
# 257  2024    ZWE       Zimbabwe           0.433317  Lower middle income
#
#      4g_cover
# 0      0.0000
# 1      0.0000
# 2      0.4600
# 3      0.5900
# 4      0.0160
# ..        ...
# 253    0.8200
# 254    0.7000
# 255    0.9985
# 256    0.9120
# 257    0.5160
#
# [258 rows x 6 columns]

# %%
# divide into year
df_grouped = (
    merged_df.groupby("year")[["mobileaccount_t_d", "4g_cover"]].mean().reset_index()
)

df_grouped
# Out:
#    year  mobileaccount_t_d  4g_cover
# 0  2014           0.066403  0.202068
# 1  2017           0.150095  0.539639
# 2  2021           0.241184  0.761094
# 3  2024           0.340629  0.909910

# %%
fig = px.line(
    df_grouped,
    x="year",
    y=["mobileaccount_t_d", "4g_cover"],
    markers=True,
    title="Average Mobile Account Rate and Population Covered by 4G",
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="1655a519-f6de-4448-8af1-cf20d8198307" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1655a519-f6de-4448-8af1-cf20d8198307")) {                    Plotly.newPlot(                        "1655a519-f6de-4448-8af1-cf20d8198307",                        [{"hovertemplate":"variable=mobileaccount_t_d\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mobileaccount_t_d","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"mobileaccount_t_d","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"3gfhB+UH6Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"XFPiUcv\u002fsD8L6fN7TTbDPzFRZHwa384\u002f8ZWTFN7M1T8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=4g_cover\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4g_cover","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"4g_cover","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"3gfhB+UH6Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"hPoBiVvdyT8KpKZnuUThP1AvXK3hWug\u002fBXKI7vsd7T8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"ba ...

# %% [markdown]
# The line chart represents how these two variables are steadily growing in the past 10 years. The average mobile account has increased from 0.0664 in 2014 to 0.3406 in 2024. 4G coverage rises aprroximately 70%.
#
# The simutanelous increasing trend is reasonable, since 4G coverage, which surpassed 90% in 2024, has created a sufficient background for the spread of mobile account.
#
# Next, I want to explore whether there are correlation of these two variables in different countries that grouped by income.

# %%
# divide into income group in 2024
df_grouped_2024 = merged_df[merged_df["year"] == 2024]

df_grouped_2024 = (
    df_grouped_2024.groupby("incomegroupwb24")[["mobileaccount_t_d", "4g_cover"]]
    .mean()
    .reset_index()
)

# order
df_grouped_2024["incomegroupwb24"] = pd.Categorical(
    df_grouped_2024["incomegroupwb24"],
    categories=[
        "Low income",
        "Lower middle income",
        "Upper middle income",
        "High income",
    ],
    ordered=True,
)
df_grouped_2024 = df_grouped_2024.sort_values("incomegroupwb24")

df_grouped_2024
# Out:
#        incomegroupwb24  mobileaccount_t_d  4g_cover
# 1           Low income           0.400050  0.774613
# 2  Lower middle income           0.314943  0.906726
# 3  Upper middle income           0.326788  0.952724
# 0          High income           0.510241  0.999667

# %%
# plot
fig = px.bar(
    df_grouped_2024,
    x="incomegroupwb24",
    y=["mobileaccount_t_d", "4g_cover"],
    barmode="group",
    title="Average of Mobile Account Rate and 4G coverage by Income Group in 2024",
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="988b6d78-95b7-4aa2-9939-5bed95a7bdae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("988b6d78-95b7-4aa2-9939-5bed95a7bdae")) {                    Plotly.newPlot(                        "988b6d78-95b7-4aa2-9939-5bed95a7bdae",                        [{"alignmentgroup":"True","hovertemplate":"variable=mobileaccount_t_d\u003cbr\u003eincomegroupwb24=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mobileaccount_t_d","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"mobileaccount_t_d","offsetgroup":"mobileaccount_t_d","orientation":"v","showlegend":true,"textposition":"auto","x":["Low income","Lower middle income","Upper middle income","High income"],"xaxis":"x","y":{"dtype":"f8","bdata":"Cjt2ZG2a2T+JG1cPBSjUP8jjuYkW6tQ\u002fiVpQneVT4D8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=4g_cover\u003cbr\u003eincomegroupwb24=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4g_cover","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"4g_cover","offsetgroup":"4g_cover","orientation":"v","showlegend":true,"textposition":"auto","x":["Low income","Lower middle income","Upper middle income","High income"],"xaxis":"x","y":{"dtype":"f8","bdata":"YVRSJ6DJ6D+AMMkW5gPtPzjPgKS2fO4\u002fZIIH80T97z8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line" ...

# %% [markdown]
# The bar chart shows the average of mobile account rate and 4G coverage by income group in 2024.
#
# It is not surprised that 4g coverage is higher in the high income countries, while it is strange that the mobile account rate is relatively high (approximately 40%) in low income country.

# %% [markdown]
# Takeaways:
#
# 1. Datasets are needed to be fully inspect and understood.
# 2. The x-axis could not automatically order as we wish, first category and then sort values to let plotly work well.
