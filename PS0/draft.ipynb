# %%
import pandas as pd

# %%
df = pd.read_csv("tables/loans_B_unlabeled.csv")
df
# Out:
#             id                  name gender  pictured  \
# 0       594676                Godwin      M         1
# 1       464810           Noy's Group      F         1
# 2       896818                 Zobia      F         1
# 3        16148                 Grace      F         1
# 4       897005              Beatrice      F         1
# ...        ...                   ...    ...       ...
# 423221  967373                 Rabea      F         1
# 423222  137923  Mujeres Unidas Group      F         1
# 423223  993001                 Abida      F         1
# 423224   90031                 Touch      M         1
# 423225  883291            Mohamed A.      M         1
#
#                                               description  loan_amount  \
# 0       Godwin is a 34-year-old married man with four ...          200
# 1       Noy, 43, is a widowed mother with six children...          350
# 2       Zobia is a housewife and a mother of four chil...          500
# ...

# %%
df_haiti = df[df["country"].str.contains("Haiti")]
len(df_haiti)
# Out:
# 786

# %%
df_haiti = df[df["country"] == "Haiti"]
len(df_haiti)
# Out:
# 786
