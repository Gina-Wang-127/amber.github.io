# %% [markdown]
# # Project 3

# %% [markdown]
# - **Dataset(s) to be used:** [SIPA alumni employment data](https://www.sipa.columbia.edu/pathways-careers/employment-statistics)
# - **Analysis question:** Is international students facing difficulty in finding jobs in U.S.?
# - **Columns that will (likely) be used:**
#   - International
#   - Outcome
#   - Job Country
#   - Citizenship Status
#   - OSA Country of Citizenship Lookup
# - **Hypothesis:**
#   - international student is less easy to be employed in U.S.
#     - Citizenship status is one of the reasons
#     - Primary language is one of the reasons

# %%
# import library
import pandas as pd

df = pd.read_excel(
    "D:/Python/PythonProject/Project 3/2023 Outcome Survey Data_Aidan.xlsx"
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 97 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   International                                                                             638 non-null    object
#  1   Filled out survey                                                                         638 non-null    object
#  2   APSIA Job Category                                                                        575 non-null    object
#  3   APSIA Sector Category                                                                     372 non-null    object
#  4   Date Reported - NEW                                                                       216 non-null    object
#  5   Outcome                                                                                   638 non-null    object
#  6   Concentration                                                                             638 non-null    object
#  7   Degree                                                                                    638 non-null    object
#  8   Sector                                                                                    468 non-null    object
#  9   Detailed Industry                                                                         474 non-null    object
#  10  Organization Name                                                                         474 non-null    object
#  11  Division                                                                                  58 non-null     object
#  12  Job Title                                                                                 474 non-null    object
#  13  Job City                                                                                  431 non-null    object
#  14  Job State                                                                                 306 non-null    object
#  15  Job Country                                                                               474 non-null    object
#  16  Job Title.1                                                                               62 non-null     object
#  17  Master Salary for Employment Statistics                                                   0 non-null      float64
#  18  Salary Range                                                                              69 non-null     object
#  19  Salary                                                                                    69 non-null     object
#  20  LinkedIn Outcome Findings                                                                 638 non-null    object
#  21  Citizenship Status                                                                        426 non-null    object
#  22  OSA Country of Citizenship Lookup                                                         638 non-null    object
#  23  Job Location State                                                                        310 non-null    object
#  24  Job Location Country                                                                      378 non-null    object
#  25  Sector.1                                                                                  372 non-null    object
#  26  Detailed Industry.1                                                                       372 non-null    object
#  27  Job Phase                                                                                 203 non-null    object
#  28  Job Source                                                                                62 non-null     object
#  29  If you are not employed, are you currently seeking employment?                            134 non-null    object
#  30  Continuing Education Full-time?                                                           0 non-null      float64
#  31  Organization Name.1                                                                       0 non-null      float64
#  32  Company Description                                                                       34 non-null     object
#  33  Include in Reporting                                                                      203 non-null    object
#  34  30 hrs per week                                                                           62 non-null     object
#  35  Approximately how many hours a week do you serve?                                         0 non-null      float64
#  36  Country where serving                                                                     60 non-null     object
#  37  Date of Offer Received                                                                    62 non-null     object
#  38  Degree to be Pursued After Graduation                                                     0 non-null      float64
#  39  Do you have a three (3) year STEM OPT visa?                                               7 non-null      object
#  40  Employer consideration for STEM                                                           3 non-null      object
#  41  Gender                                                                                    203 non-null    object
#  42  Approximately how many hours each month do you plan to volunteer?                         0 non-null      float64
#  43  Is Approved                                                                               203 non-null    object
#  44  Military Rank                                                                             0 non-null      float64
#  45  Name of School in case of Continued Education                                             2 non-null      object
#  46  Program Name                                                                              0 non-null      float64
#  47  Returning to previous employer                                                            67 non-null     object
#  48  Scope of Organization                                                                     0 non-null      float64
#  49  Self-employed                                                                             62 non-null     object
#  50  Sponsorship by Employer                                                                   62 non-null     object
#  51  Standard Job Source                                                                       62 non-null     object
#  52  What type of Own Venture is this?                                                         0 non-null      float64
#  53  What is the name of the fellowship program?                                               0 non-null      float64
#  54  What will your enrollment status be at this school?                                       0 non-null      float64
#  55  When did you actively start applying for a full-time job?                                 134 non-null    object
#  56  Why are you not seeking employment?                                                       5 non-null      object
#  57  Base Salary Pay Period                                                                    0 non-null      float64
#  58  Carried Interest Pay Period                                                               198 non-null    object
#  59  Expected Bonus Pay Period                                                                 0 non-null      float64
#  60  Expected Commission Pay Period                                                            0 non-null      float64
#  61  Guaranteed Bonus Pay Period                                                               0 non-null      float64
#  62  I'm volunteering and not currently receiving compensation                                 0 non-null      float64
#  63  Salary plus Bonuses                                                                       22 non-null     object
#  64  Total Compensation Pay Period                                                             0 non-null      float64
#  65  End Date                                                                                  6 non-null      object
#  66  Length of Commitment                                                                      0 non-null      float64
#  67  Reported Date                                                                             203 non-null    object
#  68  Start Date                                                                                67 non-null     object
#  69  What is your approximate start date?                                                      67 non-null     object
#  70  City                                                                                      60 non-null     object
#  71  Country                                                                                   60 non-null     object
#  72  Job Location                                                                              62 non-null     object
#  73  Metro Area                                                                                60 non-null     object
#  74  Postal Code                                                                               27 non-null     object
#  75  US State / Canada Province                                                                60 non-null     object
#  76  Did this job come as a result of an internship you had with this employer?                62 non-null     object
#  77  Is this a faculty position?                                                               0 non-null      float64
#  78  Is this a freelance position?                                                             0 non-null      float64
#  79  Is this a full-time position?                                                             61 non-null     object
#  80  Is this a post-graduation internship?                                                     62 non-null     object
#  81  Is this a temporary/contract job?                                                         62 non-null     object
#  82  Is this a tenured position?                                                               0 non-null      float64
#  83  Is your position a fellowship?                                                            62 non-null     object
#  84  Other Outcome Additional Details                                                          0 non-null      float64
#  85  Please provide other pertinent information about your job                                 7 non-null      object
#  86  Reason for Rejecting                                                                      0 non-null      float64
#  87  Will you be or are you currently working under Optional Practical Training (OPT) status?  62 non-null     object
#  88  Working at a Recently Founded Organization                                                62 non-null     object
#  89  Your Citizenship                                                                          200 non-null    object
#  90  Name of Employer                                                                          372 non-null    object
#  91  Name of Employer                                                                          322 non-null    object
#  92  Job Title.2                                                                               322 non-null    object
#  93  Employer Location                                                                         322 non-null    object
#  94  Start Date.1                                                                              322 non-null    object
#  95  Found on LinkedIn                                                                         638 non-null    object
#  96  Date Found on LinkedIn                                                                    638 non-null    object
# dtypes: float64(24), object(73)
# memory usage: 483.6+ KB

# %% [markdown]
# According to the output, the non-null count is better than what I expected. They are mostly concentrated in division and salary related column. To develop a valuble hypothesis and find a feasible realizing route, I need to circumvent these columns.

# %%
# data clean
df_reported = df[df["Outcome"] != "Unreported"]

df_counts = (
    df_reported.groupby(["International", "Outcome"]).size().reset_index(name="count")
)

# calculate proportion
df_counts["pct"] = df_counts.groupby("International")["count"].transform(
    lambda x: x / x.sum()
)

# %%
# plot
import plotly.express as px
from IPython.display import HTML

fig = px.bar(
    df_counts,
    x="Outcome",
    y="pct",
    color="International",
    barmode="group",
    text="pct",
    title="Outcome Distribution Within International vs Non-International Groups",
)

fig.update_layout(yaxis_title="Proportion within Group", xaxis_title="Outcome")

fig.update_traces(texttemplate="%{text:.1%}")
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="bf6ef9aa-251c-45d7-bb7b-79cf87b475e6" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bf6ef9aa-251c-45d7-bb7b-79cf87b475e6")) {                    Plotly.newPlot(                        "bf6ef9aa-251c-45d7-bb7b-79cf87b475e6",                        [{"alignmentgroup":"True","hovertemplate":"International=No\u003cbr\u003eOutcome=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"+QlxVn5C7D++Y2pg75iKPyntRkBKu4E\u002fGIZhGIZhuD8="},"textposition":"auto","x":["Job","Not seeking \u002f Other Intention","Pursuing Further Education","Still Seeking Employment"],"xaxis":"x","y":{"dtype":"f8","bdata":"+QlxVn5C7D++Y2pg75iKPyntRkBKu4E\u002fGIZhGIZhuD8="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"},{"alignmentgroup":"True","hovertemplate":"International=Yes\u003cbr\u003eOutcome=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"0rOVd1k77T+GSQ3RlFh8P4ZJDdGUWIw\u002fp+MfXJjUsD8="},"textposition":"auto","x":["Job","Not seeking \u002f Other Intention","Pursuing Further Education","Still Seeking Employment"],"xaxis":"x","y":{"dtype":"f8","bdata":"0rOVd1k77T+GSQ3RlFh8P4ZJDdGUWIw\u002fp+MfXJjUsD8="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d": ...

# %% [markdown]
# Luckily, only few students were still seeking employment. In the first quick look of the employment data, there is no significant difference between two groups, most of the students can find a job after studying in SIPA.
#
# Now let's turn to the job location, as though international students can find a job in their own country, they may still have difficulty to find a job in U.S.

# %%
df_clean = df_reported.copy()

# delete Pursuing Further Education
df_clean = df_clean[df_clean["Outcome"] == "Job"]

df_clean = df_clean[df_clean["Job Country"].notna()]

# Classify Job Country：US vs Non-US
df_clean["JobCountry_US"] = df_clean["Job Country"].apply(
    lambda x: "United States" if x == "United States" else "Non-US"
)

df_counts = (
    df_clean.groupby(["International", "JobCountry_US"])
    .size()
    .reset_index(name="count")
)

df_counts["pct"] = df_counts.groupby("International")["count"].transform(
    lambda x: x / x.sum()
)

# %%
fig = px.bar(
    df_counts,
    x="International",
    y="pct",
    color="JobCountry_US",
    barmode="relative",
    text="pct",
    title="Job Country Distribution (US vs Non-US) by International Status",
)

fig.update_traces(texttemplate="%{text:.1%}", textposition="inside")

fig.update_layout(yaxis_title="Proportion", yaxis=dict(range=[0, 1]))

HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="c8ea87ec-86e1-4ff1-a897-785ac082ebd8" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c8ea87ec-86e1-4ff1-a897-785ac082ebd8")) {                    Plotly.newPlot(                        "c8ea87ec-86e1-4ff1-a897-785ac082ebd8",                        [{"hovertemplate":"JobCountry_US=Non-US\u003cbr\u003eInternational=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Non-US","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"Hh4eHh4erj8ffPDBBx\u002fUPw=="},"textposition":"inside","x":["No","Yes"],"xaxis":"x","y":{"dtype":"f8","bdata":"Hh4eHh4erj8ffPDBBx\u002fUPw=="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"},{"hovertemplate":"JobCountry_US=United States\u003cbr\u003eInternational=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"Hh4eHh4e7j\u002fwwQcffPDlPw=="},"textposition":"inside","x":["No","Yes"],"xaxis":"x","y":{"dtype":"f8","bdata":"Hh4eHh4e7j\u002fwwQcffPDlPw=="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","ma ...

# %% [markdown]
# The hypothesis is confirmed. Apparently there is a difference between US and Non-Us students, so what cause this difference? First I inspect the citizenship status, as US company are less willing to hire non-US citizens as they do not want to afford the high H1B fee.

# %%
# data clean
df_clean_status = df_clean[df_clean["Citizenship Status"].notna()]

# %%
# count
df_counts_status = (
    df_clean_status.groupby(["Citizenship Status", "JobCountry_US"])
    .size()
    .reset_index(name="count")
)

df_counts_status["pct"] = df_counts_status.groupby("Citizenship Status")[
    "count"
].transform(lambda x: x / x.sum())

# %%
fig = px.bar(
    df_counts_status,
    x="Citizenship Status",
    y="pct",
    color="JobCountry_US",
    barmode="group",
    text="pct",
    title="Job Country (US vs Non-US) Distribution by Citizenship Status",
)

fig.update_layout(
    xaxis_title="Citizenship Status", yaxis_title="Proportion within Group"
)

fig.update_traces(texttemplate="%{text:.1%}")
HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="04e77a06-a5fd-46de-9854-0636af930f34" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("04e77a06-a5fd-46de-9854-0636af930f34")) {                    Plotly.newPlot(                        "04e77a06-a5fd-46de-9854-0636af930f34",                        [{"alignmentgroup":"True","hovertemplate":"JobCountry_US=Non-US\u003cbr\u003eCitizenship Status=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Non-US","offsetgroup":"Non-US","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA0D9\u002fIuGU5sXPP6uqqqqqquo\u002fmpmZmZmZ2T8Oh8PhcDisPw=="},"textposition":"auto","x":["Employment (H-1) Visa","F1 Visa","J1 Visa","Other","US Citizen"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA0D9\u002fIuGU5sXPP6uqqqqqquo\u002fmpmZmZmZ2T8Oh8PhcDisPw=="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"},{"alignmentgroup":"True","hovertemplate":"JobCountry_US=United States\u003cbr\u003eCitizenship Status=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA6D9gt8dahg7oP1VVVVVVVcU\u002fMzMzMzMz4z+Px+PxeDzuPwAAAAAAAPA\u002f"},"textposition":"auto","x":["Employment (H-1) Visa","F1 Visa","J1 Visa","Other","US Citizen","US Permanent Resident"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA6D9gt8dahg7oP1VVVVVVVcU\u002fMzMzMzMz4z+Px+PxeDzuPwAAAAAAAPA\u002f"},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %% [markdown]
# The data clearly indicates that international students (F-1, J-1, H-1) are significantly less likely to obtain U.S.-based jobs compared to U.S. citizens or permanent residents, suggesting they face considerable difficulty securing employment in the United States.

# %% [markdown]
# Next, the reason why international students do not stay in US could also be the lack of English speaking ability. So I divide the country into English-speaking and Non-English speaking to find if there is any difference.
#
# To define which country is English speaking, I use ChatGPT to help me build a list of English speaking countries according to the [List of countries and territories where English is an official language](https://en.wikipedia.org/wiki/List_of_countries_and_territories_where_English_is_an_official_language?utm_source=chatgpt.com) on wikipedia.

# %%
df_clean_language = df_clean.copy()

# data clean
df_clean_language["citizenship_country_clean"] = (
    df_clean_language["OSA Country of Citizenship Lookup"]
    .astype(str)
    .str.strip()
    .str.upper()
)

# repeated country name
alias_mapping = {
    "UNITED STATES (USA)": "UNITED STATES",
    "UNITED STATES OF AMERICA": "UNITED STATES",
}
df_clean_language["citizenship_country_clean"] = df_clean_language[
    "citizenship_country_clean"
].replace(alias_mapping)

# English country list
english_countries = {
    "ANTIGUA AND BARBUDA",
    "AUSTRALIA",
    "BAHAMAS",
    "BARBADOS",
    "BELIZE",
    "BOTSWANA",
    "CAMEROON",
    "CANADA",
    "DOMINICA",
    "ESWATINI",
    "FIJI",
    "GAMBIA",
    "GHANA",
    "GRENADA",
    "GUYANA",
    "INDIA",
    "IRELAND",
    "JAMAICA",
    "KENYA",
    "KIRIBATI",
    "LESOTHO",
    "LIBERIA",
    "MALAWI",
    "MALTA",
    "MARSHALL ISLANDS",
    "MAURITIUS",
    "MICRONESIA",
    "NAMIBIA",
    "NAURU",
    "NEW ZEALAND",
    "NIGERIA",
    "PAKISTAN",
    "PALAU",
    "PAPUA NEW GUINEA",
    "PHILIPPINES",
    "RWANDA",
    "SAINT KITTS AND NEVIS",
    "SAINT LUCIA",
    "SAINT VINCENT AND THE GRENADINES",
    "SAMOA",
    "SEYCHELLES",
    "SIERRA LEONE",
    "SINGAPORE",
    "SOLOMON ISLANDS",
    "SOUTH AFRICA",
    "SOUTH SUDAN",
    "SRI LANKA",
    "SUDAN",
    "TANZANIA",
    "TONGA",
    "TRINIDAD AND TOBAGO",
    "TUVALU",
    "UGANDA",
    "UNITED KINGDOM",
    "UNITED STATES",
    "VANUATU",
    "ZAMBIA",
    "ZIMBABWE",
}

# classify
df_clean_language["citizenship_english_country"] = df_clean_language[
    "citizenship_country_clean"
].apply(lambda x: "English-speaking" if x in english_countries else "Non-English")

# count proportion
df_counts_language = (
    df_clean_language.groupby(["citizenship_english_country", "JobCountry_US"])
    .size()
    .reset_index(name="count")
)

df_counts_language["pct"] = df_counts_language.groupby("citizenship_english_country")[
    "count"
].transform(lambda x: x / x.sum())

# %%
fig = px.bar(
    df_counts_language,
    x="citizenship_english_country",
    y="pct",
    color="JobCountry_US",
    barmode="relative",
    text="pct",
    title="Job Country (US vs Non-US) by Citizenship Language Background",
)

fig.update_traces(texttemplate="%{text:.1%}", textposition="inside")

fig.update_layout(
    yaxis_title="Proportion",
    xaxis_title="Citizenship Country Language Background",
    yaxis=dict(range=[0, 1]),
    bargap=0.2,
)

HTML(fig.to_html(include_plotlyjs="cdn", full_html=False))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="122cd58b-cffc-43cd-ad34-25545d865e47" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("122cd58b-cffc-43cd-ad34-25545d865e47")) {                    Plotly.newPlot(                        "122cd58b-cffc-43cd-ad34-25545d865e47",                        [{"hovertemplate":"JobCountry_US=Non-US\u003cbr\u003ecitizenship_english_country=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Non-US","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"TGV71wHduD98bolTv+fWPw=="},"textposition":"inside","x":["English-speaking","Non-English"],"xaxis":"x","y":{"dtype":"f8","bdata":"TGV71wHduD98bolTv+fWPw=="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"},{"hovertemplate":"JobCountry_US=United States\u003cbr\u003ecitizenship_english_country=%{x}\u003cbr\u003epct=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"V5MQxV\u002fk7D\u002fCSDtWIIzkPw=="},"textposition":"inside","x":["English-speaking","Non-English"],"xaxis":"x","y":{"dtype":"f8","bdata":"V5MQxV\u002fk7D\u002fCSDtWIIzkPw=="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outli ...

# %% [markdown]
# From the chart above, it is possible that Language background is one of the factors that make the gap.

# %% [markdown]
# Overall, an international student may find difficulty in applying jobs in U.S. because of their citizenship status and language.
